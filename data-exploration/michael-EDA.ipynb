# %% [markdown]
# # Initial EDA

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import json
import gzip
import os
import random

random.seed(42) # seeding for rerunning purposes

# %%
head = 'goodreads_books_children.json.gz'
filename_test = os.path.join(root, head)
with gzip.open(filename_test) as file: 
    for l in file:
        d = json.loads(l)
        print(d['book_id'])
        break
# Out:
# 287141

# %%
def load_data(file_name, head = 2999):
    count = 0
    data = []
    with gzip.open(file_name) as fin:
        # non performant for all data
        for l in fin:
            d = json.loads(l)
            count += 1
            data.append(d)
            
            # break point > head
            #### NEED BETTER WAY TO GET ALL INFORMATION ####
            if (head is not None) and (count > head):
                break
    return data 

def combine_data(root):
    predefined_genres = os.listdir(root)
    print('')
    
    data_agg = []
    for genre in predefined_genres:
        raw_data = load_data(os.path.join(root, genre))
        selected_books = random.sample(raw_data, 1000) # sample 1000 without replacement, list 
        data_agg.append(selected_books)
        
    final_book_data = [book for selected_books in data_agg for book in selected_books]
    return pd.DataFrame(final_book_data)

# %%
#### Feel free to change to whatever the data is located (removed data from Git due to size haha)
root = r'/Users/michaelfronda/Desktop/Main/OMSA/22-FA-ISYE6740/Project-data'

# %%
df = combine_data(root)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   isbn                  7000 non-null   object
#  1   text_reviews_count    7000 non-null   object
#  2   series                7000 non-null   object
#  3   country_code          7000 non-null   object
#  4   language_code         7000 non-null   object
#  5   popular_shelves       7000 non-null   object
#  6   asin                  7000 non-null   object
#  7   is_ebook              7000 non-null   object
#  8   average_rating        7000 non-null   object
#  9   kindle_asin           7000 non-null   object
#  10  similar_books         7000 non-null   object
#  11  description           7000 non-null   object
#  12  format                7000 non-null   object
#  13  link                  7000 non-null   object
#  14  authors               7000 non-null   object
#  15  publisher             7000 non-null   object
#  16  num_pages             7000 non-null   object
#  17  publication_day       7000 non-null   object
#  18  isbn13                7000 non-null   object
#  19  publication_month     7000 non-null   object
#  20  edition_information   7000 non-null   object
#  21  publication_year      7000 non-null   object
#  22  url                   7000 non-null   object
#  23  image_url             7000 non-null   object
#  24  book_id               7000 non-null   object
#  25  ratings_count         7000 non-null   object
#  26  work_id               7000 non-null   object
#  27  title                 7000 non-null   object
#  28  title_without_series  7000 non-null   object
# dtypes: object(29)
# memory usage: 1.5+ MB

# %%
interactions_children = pd.DataFrame(load_data(os.path.join(root, 'goodreads_interactions_children.json.gz'), head=99999))

# %%
len(interactions_children)
# Out:
# 100000

# %%
is_read = interactions_children[interactions_children['is_read'] == True]['book_id'].unique()

# %%
np.size(is_read)
# Out:
# 19009

# %%
def load_data2(file_name, head = 999):
    count = 0
    data = []
    with gzip.open(file_name) as fin:
        # non performant for all data
        for l in fin:
            d = json.loads(l)
            if d['book_id'] in is_read:
                count += 1
                data.append(d)
            
            # break point > head
            #### NEED BETTER WAY TO GET ALL INFORMATION ####
            if (head is not None) and (count > head):
                break
    return data 

children_books_read = load_data2(os.path.join(root, 'goodreads_books_children.json.gz'))

# %%
children_books_read[0]['book_id']
# Out:
# '6066812'

# %%
reviews_children = pd.DataFrame(load_data(os.path.join(root, 'goodreads_reviews_children.json.gz'),head=999999))

# %%
reviews_children.sample(2)
# Out:
#                                 user_id   book_id  \
# 73871  0806f14a989d4c5c6057f5155f009df8  30312747
# 12316  da76b2e808d445af86cc59044dda319e    138959
#
#                               review_id  rating  \
# 73871  075adfb3c59b82ff8ce0819940ffe844       5
# 12316  edc763332f193ba0750136cacef54220       3
#
#                                              review_text  \
# 73871  Beautiful illustrations + great for discussion...
# 12316  This was not at all like the movie, but still ...
#
#                            date_added                    date_updated  \
# 73871  Sat Apr 01 08:05:10 -0700 2017  Sat Apr 01 08:07:01 -0700 2017
# 12316  Wed May 29 03:46:38 -0700 2013  Mon Jun 17 19:23:44 -0700 2013
#
#                               read_at                      started_at  \
# 73871  Wed Mar 01 00:00:00 -0800 2017
# 12316  Mon Jun 17 00:00:00 -0700 2013  Wed May 29 00:00:00 -0700 2013
#
#        n_votes  n_comments
# 73871        0           0
# 12316        0           0

# %%
df_children = pd.DataFrame(children_books_read)

# %%
combined = pd.merge(df_children, reviews_children, how='left', on=['book_id'])

# %%
combined[combined['book_id'] == '10806008'].T
# Out:
#                                                                     60   \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                b710ade46b23d104084d8b7c1c656d07
# review_id                              8198d6c9f4d4e4ff69681bdcfd9d6d27
# rating                                                                5
# review_text           This is one of the best new YA books I have re...
# date_added                               Sun Jun 10 14:14:31 -0700 2012
# date_updated                             Sun Jun 10 14:15:28 -0700 2012
# read_at                                  Tue May 01 00:00:00 -0700 2012
# started_at
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     61   \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                da4dc1bba6b2e9b5eb0799aa1e16216a
# review_id                              e1047f97a1fc2ea7dada559c41c19e15
# rating                                                                5
# review_text           Honestly, this book was fantastic (heh, heh), ...
# date_added                               Thu Jun 12 08:34:25 -0700 2014
# date_updated                             Sat Jun 21 06:45:17 -0700 2014
# read_at                                  Sat Jun 21 06:45:17 -0700 2014
# started_at                               Thu Jun 12 00:00:00 -0700 2014
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     62   \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                05a9bc6aa3513d0c43f3167bb16de8e2
# review_id                              dd2003cb1267f23076b54f6f65fcedfa
# rating                                                                5
# review_text           AMAZING \n I loved it. There were certainly ve...
# date_added                               Wed Jun 20 03:41:55 -0700 2012
# date_updated                             Fri Aug 15 14:20:30 -0700 2014
# read_at                                  Fri Aug 01 00:00:00 -0700 2014
# started_at
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     63   \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                271cca0a5f61ce9ccb0c92461093547b
# review_id                              c51c5b2f53882b6bf559bebe9d750225
# rating                                                                5
# review_text           What an incredible story! Loved the adventure,...
# date_added                               Sun Mar 02 15:03:17 -0800 2014
# date_updated                             Sun Mar 02 15:04:49 -0800 2014
# read_at                                  Sun Mar 02 15:04:49 -0800 2014
# started_at
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     64   \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                5ad67423a5435bd2fa07b08eec6689ac
# review_id                              8d36cc07408beaba6d57415caa26ae8a
# rating                                                                5
# review_text           Wow, this book took me by surprise. It was fan...
# date_added                               Sun Jan 05 11:18:16 -0800 2014
# date_updated                             Mon Jun 30 12:06:50 -0700 2014
# read_at                                  Tue Jun 24 00:00:00 -0700 2014
# started_at
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     65   \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                7f9e0143eff3380349e1113e9654de94
# review_id                              45ff64671096714a905c229d82cc1aaf
# rating                                                                5
# review_text           This book felt a little dark for a children's ...
# date_added                               Sat May 27 19:38:48 -0700 2017
# date_updated                             Mon May 29 16:31:09 -0700 2017
# read_at                                  Sun May 28 00:00:00 -0700 2017
# started_at                               Sat May 27 00:00:00 -0700 2017
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     66   \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                3a009c2442ae08de552ce99c26f2cedc
# review_id                              c6ae908692ac3bf1a4e753b69ec383b9
# rating                                                                3
# review_text           3.5 My kids and husband would probably give th...
# date_added                               Sat Sep 02 06:59:31 -0700 2017
# date_updated                             Tue Oct 24 13:03:46 -0700 2017
# read_at                                  Sat Sep 09 18:00:41 -0700 2017
# started_at                               Sat Sep 02 06:59:38 -0700 2017
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     67   \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                adb3aa6a33c43ec6dfcbc9157734c2c5
# review_id                              2371906a012a9497b302c42f32a7c4e3
# rating                                                                5
# review_text           I absolutely loved "The Night Gardener," so wh...
# date_added                               Sun Feb 12 05:56:51 -0800 2017
# date_updated                             Thu Apr 27 15:25:56 -0700 2017
# read_at                                  Thu Apr 27 15:25:56 -0700 2017
# started_at                               Sun Apr 16 00:00:00 -0700 2017
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     68   \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                2c412515ee9a4e4d1fb36b4e3d51d2ab
# review_id                              bdc83a11ce53e4017ebfe6998eb75e87
# rating                                                                3
# review_text           I rather enjoyed diving into Peter Nimble's wo...
# date_added                               Mon Jan 30 14:00:40 -0800 2017
# date_updated                             Tue Feb 28 12:59:46 -0800 2017
# read_at                                  Tue Feb 28 12:59:46 -0800 2017
# started_at                               Wed Feb 22 19:26:40 -0800 2017
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     69   ...  \
# isbn                                                         1419700251  ...
# text_reviews_count                                                  890  ...
# series                                                         [799654]  ...
# country_code                                                         US  ...
# language_code                                                     en-US  ...
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...  ...
# asin                                                                     ...
# is_ebook                                                          false  ...
# average_rating                                                     4.04  ...
# kindle_asin                                                  B006LGNU40  ...
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...  ...
# description           Peter Nimble and His Fantastic Eyesis the utte...  ...
# format                                                        Hardcover  ...
# link                  https://www.goodreads.com/book/show/10806008-p...  ...
# authors                          [{'author_id': '4722094', 'role': ''}]  ...
# publisher                                                  Amulet Books  ...
# num_pages                                                           400  ...
# publication_day                                                       1  ...
# isbn13                                                    9781419700255  ...
# publication_month                                                     8  ...
# edition_information                                                      ...
# publication_year                                                   2011  ...
# url                   https://www.goodreads.com/book/show/10806008-p...  ...
# image_url             https://images.gr-assets.com/books/1353594747m...  ...
# book_id                                                        10806008  ...
# ratings_count                                                      6049  ...
# work_id                                                        15719446  ...
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...  ...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...  ...
# user_id                                8a79d0ed286d58193cb9bdc8498df6d9  ...
# review_id                              bef2a82ff4ed3cc1310867d31066691b  ...
# rating                                                                4  ...
# review_text           Wow! Quite blood-thirsty for a middle-grade no...  ...
# date_added                               Sun May 22 16:55:50 -0700 2011  ...
# date_updated                             Tue Nov 15 22:28:26 -0800 2011  ...
# read_at                                  Tue Nov 15 00:00:00 -0800 2011  ...
# started_at                               Mon Nov 14 00:00:00 -0800 2011  ...
# n_votes                                                               0  ...
# n_comments                                                            0  ...
#
#                                                                     250  \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                1ec587e0b2c9111af8c071ac810e7504
# review_id                              c4e01692d7a41123f283912d2d896dae
# rating                                                                5
# review_text           Full review is here @ Fictionbookreview.com \n...
# date_added                               Sun Apr 17 20:08:08 -0700 2016
# date_updated                             Wed Jun 29 23:18:59 -0700 2016
# read_at                                  Sat Jun 04 00:00:00 -0700 2016
# started_at                               Thu May 26 00:00:00 -0700 2016
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     251  \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                3a3ad2cb99546e7f47364cb95ceb02b2
# review_id                              41ef1eca16978f7f5a438de538d307b4
# rating                                                                4
# review_text           What a fantastic book! I don't even remember w...
# date_added                               Fri Jul 08 15:47:15 -0700 2011
# date_updated                             Fri Jan 13 18:33:12 -0800 2012
# read_at                                  Thu Jan 12 00:00:00 -0800 2012
# started_at
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     252  \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                e325840c8af66997a1877c7730365d05
# review_id                              501cc56f4e64577dc42c6e4d21216e00
# rating                                                                4
# review_text           One of the best stories I have read. Magical i...
# date_added                               Mon Dec 19 09:01:14 -0800 2016
# date_updated                             Mon Feb 20 11:02:34 -0800 2017
# read_at                                  Mon Feb 20 11:02:34 -0800 2017
# started_at                               Mon Dec 19 09:01:15 -0800 2016
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     253  \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                78b46da957aff701be9e890f6efe244c
# review_id                              70162125876fc28cd208db1413634506
# rating                                                                2
# review_text           The book reminded me of a combination of Olive...
# date_added                               Tue Oct 07 21:24:44 -0700 2014
# date_updated                             Tue Dec 08 13:23:56 -0800 2015
# read_at                                  Thu Oct 09 00:00:00 -0700 2014
# started_at                               Tue Oct 07 00:00:00 -0700 2014
# n_votes                                                               1
# n_comments                                                            0
#
#                                                                     254  \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                8158176523f7eb24d07f4891612fc4e7
# review_id                              db08d84a59f5dcea2af942822ffd6e4f
# rating                                                                3
# review_text           The first half of this is written in a knowing...
# date_added                               Wed Jun 13 08:09:29 -0700 2012
# date_updated                             Fri Feb 21 07:22:38 -0800 2014
# read_at                                  Thu Feb 20 00:00:00 -0800 2014
# started_at                               Wed Feb 12 00:00:00 -0800 2014
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     255  \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                7dbb10847e01ef0e537681bbf316986e
# review_id                              3e0ec1b52d7abffbe1a4f2a6ba1fc7da
# rating                                                                2
# review_text                                     This is book seven (7).
# date_added                               Mon Apr 22 23:25:23 -0700 2013
# date_updated                             Mon Jan 04 10:14:13 -0800 2016
# read_at                                  Tue Dec 22 00:00:00 -0800 2015
# started_at                               Tue Dec 15 00:00:00 -0800 2015
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     256  \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                f21745a573dde35681ac604de5f578ce
# review_id                              a7da7e12694c430dbf206d3e65e3a49c
# rating                                                                4
# review_text           I read somewhere that a great author teaches y...
# date_added                               Fri Apr 06 14:19:57 -0700 2012
# date_updated                             Wed Jan 09 06:42:06 -0800 2013
# read_at                                  Wed Jan 09 06:42:06 -0800 2013
# started_at                               Fri Apr 06 00:00:00 -0700 2012
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     257  \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                4f46db8f01dacfcc854977213bbdb53f
# review_id                              fd82042e603542376f8c6184811ce216
# rating                                                                3
# review_text           This book was just full of imaginative twists ...
# date_added                               Tue May 20 07:57:36 -0700 2014
# date_updated                             Tue May 20 08:01:52 -0700 2014
# read_at                                  Thu May 08 00:00:00 -0700 2014
# started_at
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     258  \
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                528b5ad6ac0d51068eee38427755fb1c
# review_id                              cdf1c59361de127a90af4a020e9431c5
# rating                                                                5
# review_text           Good kid's books can often be hard to find. Ei...
# date_added                               Thu Aug 11 00:20:17 -0700 2011
# date_updated                             Thu Aug 11 00:24:05 -0700 2011
# read_at
# started_at
# n_votes                                                               0
# n_comments                                                            0
#
#                                                                     259
# isbn                                                         1419700251
# text_reviews_count                                                  890
# series                                                         [799654]
# country_code                                                         US
# language_code                                                     en-US
# popular_shelves       [{'count': '10607', 'name': 'to-read'}, {'coun...
# asin
# is_ebook                                                          false
# average_rating                                                     4.04
# kindle_asin                                                  B006LGNU40
# similar_books         [9464855, 9869553, 12849210, 10178007, 1271115...
# description           Peter Nimble and His Fantastic Eyesis the utte...
# format                                                        Hardcover
# link                  https://www.goodreads.com/book/show/10806008-p...
# authors                          [{'author_id': '4722094', 'role': ''}]
# publisher                                                  Amulet Books
# num_pages                                                           400
# publication_day                                                       1
# isbn13                                                    9781419700255
# publication_month                                                     8
# edition_information
# publication_year                                                   2011
# url                   https://www.goodreads.com/book/show/10806008-p...
# image_url             https://images.gr-assets.com/books/1353594747m...
# book_id                                                        10806008
# ratings_count                                                      6049
# work_id                                                        15719446
# title                 Peter Nimble and His Fantastic Eyes (Peter Nim...
# title_without_series  Peter Nimble and His Fantastic Eyes (Peter Nim...
# user_id                                3510c6cd224fd9670fd519aaef4c22b9
# review_id                              ce6db876969950075edae3e7cc87943e
# rating                                                                2
# review_text           Jonathan Auxier's debut book, Peter Nimble and...
# date_added                               Thu Aug 25 16:54:08 -0700 2011
# date_updated                             Tue Sep 06 13:19:23 -0700 2011
# read_at                                  Fri Aug 26 00:00:00 -0700 2011
# started_at                               Thu Aug 25 00:00:00 -0700 2011
# n_votes                                                               7
# n_comments                                                            1
#
# [39 rows x 200 columns]

# %%
combined['text'] = combined[['book_id','review_text']].groupby(['book_id'])['review_text'].transform(lambda x: '\t'.join(x))

# %%
bid_rev = combined[['book_id', 'text']].drop_duplicates()

# %%
final_final = pd.merge(df_children, bid_rev, how='inner', on=['book_id'])

# %%
# scale this process to each genre!!! 
final_final
# Out:
#            isbn text_reviews_count     series country_code language_code  \
# 0    1934876569                  6   [151854]           US
# 1    0590417010                193         []           US           eng
# 2    0531301060                  3         []           US
# 3    9512310201                  1   [223802]           US           fin
# 4    0374428115                  7         []           US
# ..          ...                ...        ...          ...           ...
# 995  0141301074                110         []           US           eng
# 996  9025833926                105   [522686]           US            nl
# 997  0688099386                  8   [691570]           US           eng
# 998  0544939077                 48  [1131304]           US
# 999  1907967508                 55         []           US
#
#                                        popular_shelves asin is_ebook  \
# 0    [{'count': '515', 'name': 'to-read'}, {'count'...         false
# 1    [{'count': '450', 'name': 'to-read'}, {'count'...         false
# 2    [{'count': '10', 'name': 'to-read'}, {'count':...         false
# 3    [{'count': '4', 'name': 'to-read'}, {'count': ...         false
# 4    [{'count': '32', 'name': 'to-read'}, {'count':...         false
# ..                                                 ...  ...      ...
# 995  [{'count': '1199', 'name': 'to-read'}, {'count...         false
# 996  [{'count': '2528', 'name': 'to-read'}, {'count...         false
# 997  [{'count': '25', 'name': 'to-read'}, {'count':...         false
# 998  [{'count': '14', 'name': 'to-read'}, {'count':...         false
# 999  [{'count': '70', 'name': 'to-read'}, {'count':...         false
#
#     average_rating kindle_asin  ... edition_information publication_year  \
# 0             4.22              ...                                 2009
# 1             4.43  B017RORXNI  ...                                 1995
# 2             3.68              ...                                 1999
# 3             3.53              ...                                 1976
# 4             4.38              ...                                 2008
# ..             ...         ...  ...                 ...              ...
# 995           3.94  B0096HFOZO  ...                                 1998
# 996           4.15              ...                                 2003
# 997           3.66              ...
# 998           3.87  B01N5F6FQI  ...                                 2017
# 999           3.57              ...                                 2013
#
#                                                    url  \
# 0    https://www.goodreads.com/book/show/6066812-al...
# 1    https://www.goodreads.com/book/show/89378.Dog_...
# 2    https://www.goodreads.com/book/show/2592648-it...
# 3    https://www.goodreads.com/book/show/8030991-ka...
# 4    https://www.goodreads.com/book/show/926662.Gro...
# ..                                                 ...
# 995  https://www.goodreads.com/book/show/430537.The...
# 996  https://www.goodreads.com/book/show/1835829.De...
# 997  https://www.goodreads.com/book/show/4987435-sc...
# 998  https://www.goodreads.com/book/show/30971640-w...
# 999  https://www.goodreads.com/book/show/15843330-d...
#
#                                              image_url   book_id  \
# 0    https://images.gr-assets.com/books/1316637798m...   6066812
# 1    https://images.gr-assets.com/books/1360057676m...     89378
# 2    https://s.gr-assets.com/assets/nophoto/book/11...   2592648
# 3    https://images.gr-assets.com/books/1295309151m...   8030991
# 4    https://s.gr-assets.com/assets/nophoto/book/11...    926662
# ..                                                 ...       ...
# 995  https://images.gr-assets.com/books/1327868821m...    430537
# 996  https://s.gr-assets.com/assets/nophoto/book/11...   1835829
# 997  https://s.gr-assets.com/assets/nophoto/book/11...   4987435
# 998  https://images.gr-assets.com/books/1473599117m...  30971640
# 999  https://images.gr-assets.com/books/1354905145m...  15843330
#
#     ratings_count   work_id  \
# 0              98    701117
# 1            1331     86259
# 2              21   2613165
# 3              34  12634950
# 4              45    911665
# ..            ...       ...
# 995          1598    866909
# 996          4224   1329309
# 997            25   5053308
# 998           150  51589424
# 999           235  21585621
#
#                                                  title  \
# 0    All's Fairy in Love and War (Avalon: Web of Ma...
# 1                                           Dog Heaven
# 2               It's Funny Where Ben's Train Takes Him
# 3                                 Katso eteesi, Lotta!
# 4              Growltiger's Last Stand and Other Poems
# ..                                                 ...
# 995                                          The Twits
# 996                            De brief voor de koning
# 997                     School's Out (Class Clown, #4)
# 998        What Is Chasing Duck? (The Giggle Gang, #1)
# 999                                        Dino Bites!
#
#                                   title_without_series  \
# 0    All's Fairy in Love and War (Avalon: Web of Ma...
# 1                                           Dog Heaven
# 2               It's Funny Where Ben's Train Takes Him
# 3                                 Katso eteesi, Lotta!
# 4              Growltiger's Last Stand and Other Poems
# ..                                                 ...
# 995                                          The Twits
# 996                            De brief voor de koning
# 997                     School's Out (Class Clown, #4)
# 998        What Is Chasing Duck? (The Giggle Gang, #1)
# 999                                        Dino Bites!
#
#                                                   text
# 0    This was a really cute book, though to be hone...
# 1    Really cute, sweet, and charming.\tThis beauti...
# 2    Rated and reviewed by Dylan, age 7: \n This bo...
# 3    Ihan normaali Lotta-kirja, nakojaan luen kaikk...
# 4    Beatifully illustrated, classic children's tal...
# ..                                                 ...
# 995  How can you not like Roald Dahl?\tFalse\tRead ...
# 996  A really lovely story. Reading it as an adult ...
# 997  The "Class Clown" is back!Lucas Cott is ready ...
# 998  What's chasing Duck? It has big teeth and is s...
# 999  A hungry dinosaur is looking for lunch and his...
#
# [1000 rows x 30 columns]

# %%
final_final.loc[999]['text']
# Out:
# 'A hungry dinosaur is looking for lunch and his lunch is looking for a snack who\'s looking for a bite to eat. With all of these creatures wiggling around in the dinosaur\'s stomach he lets out a monster burp and everyone escapes! \n A funny read aloud that brings to mind the Old Lady who Swallowed a Fly.\tcumulative picture book where each creature munches on the smaller one and all are devoured by a hungry T-Rex.\tCute -- dinosaur storytime possibility.\tThis book is perfect for ECE and read aloud! It is the story of a dinosaur who is looking for his lunch (and what the lunch itself is looking to eat). It is a great sequence book with good vocabulary, large text and pictures, and a simple story. Awesome!\tGood for Dino fans and Dino themed ST. Also good for "I\'m Gonna Eat You Up" story time.\tDemonstrates chain reactions/cause and effect well. May upset younger audiences, but hey, it\'s the circle of life.\tI had tremendous success in storytime with this one. The kids loved it! Short, sweet, and funny!\tThis is a nice twist on Old Woman Who swallowed a fly. Toddler style, neon pages.\tA reverse in the food chain riot. -Monty K.\tE\tThis is a very simple book and is geared more toward younger children. The illustrations are interesting though.\tOne of the shortest dinosaur books you will ever read! Three dinosaurs are looking for something to eat. They find their prey and give a chomp. Soon after their bite, their meals backfire with a giant belch! \n The book is fast paced, but fun and interesting. The illustrations could be considered minimalistic, but they highlight the action and the minimal words per page. The dinosaurs jump to the forefront because of the solid color pages with no background illustrations. In a small group setting, the reader can expand on the topics of the book and create a fun book talk about the food chain or digestion. \n Theme: Dinosaurs \n Additional themes: eating, cumulative, cause and effect, food chain \n Reviewed from a library copy.\tThis is a kind of cute, kind of off the wall picture book about a food chain looking for their next meal and then burping each other up at the end. I think boys would like it.\tCute, simple. Somewhat akin to I Know an Old Lady, but without the rhyme and repetition.\tLittle bit loved it; I thought it was inane.\tI walked between three and four stars on this one. The concept is simple, but the story is amusing to my boy and I. Its a simple book and suffers from deminishing returns. Still, it is a fun book that we occasionally borrow.\tFunny, but a little disturbing at the same time. Might not be a good read for very sensitive kids.\tCute and simple....though a little morbid.'

# %%
# Monday 
# TODO: scale process to get review data for 1000 books for each pre defined genre
# TODO: Initial Clusters

# %%
# Tuesday 
# TODO: Continue Clustering books, different methods?

# %%
raw_data.sample(10)
# Out:
#             isbn text_reviews_count    series country_code language_code  \
# 3556  1467712345                 27        []           US
# 4727  0340917555                 53  [146020]           US         en-GB
# 335   0750013931                  3  [381005]           US
# 584   0823424006                 25        []           US
# 8990  9953875367                  3        []           US           ara
# 9120  1612440916                  6        []           US         en-US
# 8751                              3  [155079]           US           eng
# 5684  8877828226                  2  [206569]           US           ita
# 5131                              1        []           US
# 6135                              1        []           US
#
#                                         popular_shelves        asin is_ebook  \
# 3556  [{'count': '38', 'name': 'to-read'}, {'count':...                false
# 4727  [{'count': '1012', 'name': 'to-read'}, {'count...                false
# 335   [{'count': '224', 'name': 'to-read'}, {'count'...                false
# 584   [{'count': '23', 'name': 'to-read'}, {'count':...                false
# 8990  [{'count': '2505', 'name': 'to-read'}, {'count...                false
# 9120  [{'count': '187', 'name': 'to-read'}, {'count'...                false
# 8751  [{'count': '89', 'name': 'to-read'}, {'count':...                false
# 5684  [{'count': '216', 'name': 'to-read'}, {'count'...                false
# 5131  [{'count': '568', 'name': 'to-read'}, {'count'...  B00JMV8TAG     true
# 6135  [{'count': '976', 'name': 'to-read'}, {'count'...                false
#
#      average_rating kindle_asin  ... publication_month edition_information  \
# 3556           3.26  B00SG65DMU  ...                 4
# 4727           3.78  B007LO1KVQ  ...
# 335            4.23              ...
# 584            3.47              ...                 2
# 8990           3.90              ...
# 9120           4.17  B008AK7ALE  ...                 8
# 8751           3.96  B00GVFU7R4  ...
# 5684           3.95              ...                 1       Brutte Storie
# 5131           4.05  B00JMV8TAG  ...
# 6135           3.89              ...
#
#      publication_year                                                url  \
# 3556             2015  https://www.goodreads.com/book/show/19354685-t...
# 4727             2006  https://www.goodreads.com/book/show/124675.The...
# 335                    https://www.goodreads.com/book/show/1914630.Th...
# 584              2012  https://www.goodreads.com/book/show/12710065-f...
# 8990             2008        https://www.goodreads.com/book/show/8082219
# 9120             2012  https://www.goodreads.com/book/show/15831747-v...
# 8751             2009  https://www.goodreads.com/book/show/1137256.Ca...
# 5684             1999  https://www.goodreads.com/book/show/9749359-i-...
# 5131                   https://www.goodreads.com/book/show/22930358-a...
# 6135                   https://www.goodreads.com/book/show/26217381-g...
#
#                                               image_url   book_id  \
# 3556  https://images.gr-assets.com/books/1416180554m...  19354685
# 4727  https://images.gr-assets.com/books/1415582629m...    124675
# 335   https://s.gr-assets.com/assets/nophoto/book/11...   1914630
# 584   https://images.gr-assets.com/books/1328019578m...  12710065
# 8990  https://s.gr-assets.com/assets/nophoto/book/11...   8082219
# 9120  https://images.gr-assets.com/books/1367002342m...  15831747
# 8751  https://images.gr-assets.com/books/1338051257m...   1137256
# 5684  https://images.gr-assets.com/books/1445556344m...   9749359
# 5131  https://s.gr-assets.com/assets/nophoto/book/11...  22930358
# 6135  https://images.gr-assets.com/books/1441263911m...  26217381
#
#      ratings_count   work_id  \
# 3556            81  27415839
# 4727          3205    120063
# 335             41     80619
# 584             87  17843561
# 8990             6   1021311
# 9120            13  21373662
# 8751            14   1124501
# 5684            15    413020
# 5131            13   3719102
# 6135            23   2801485
#
#                                                   title  \
# 3556                                     Trash Mountain
# 4727  The Secret Seven Adventure (The Secret Seven, #2)
# 335       The Oaken Throne (The Deptford Histories, #2)
# 584                   Fox Tails: Four Fables from Aesop
# 8990                                      عفريت الأرقام
# 9120                             Vin and the Dorky Duet
# 8751               Caddy Ever After (Casson Family, #4)
# 5684                                     I cinici celti
# 5131  AN OLD-FASHIONED GIRL. (Annotated) (Louisa May...
# 6135                                     Gümüş Patenler
#
#                                    title_without_series
# 3556                                     Trash Mountain
# 4727  The Secret Seven Adventure (The Secret Seven, #2)
# 335       The Oaken Throne (The Deptford Histories, #2)
# 584                   Fox Tails: Four Fables from Aesop
# 8990                                      عفريت الأرقام
# 9120                             Vin and the Dorky Duet
# 8751               Caddy Ever After (Casson Family, #4)
# 5684                                     I cinici celti
# 5131  AN OLD-FASHIONED GIRL. (Annotated) (Louisa May...
# 6135                                     Gümüş Patenler
#
# [10 rows x 29 columns]

# %%
raw_data.columns
# Out:
# Index(['isbn', 'text_reviews_count', 'series', 'country_code', 'language_code',
#        'popular_shelves', 'asin', 'is_ebook', 'average_rating', 'kindle_asin',
#        'similar_books', 'description', 'format', 'link', 'authors',
#        'publisher', 'num_pages', 'publication_day', 'isbn13',
#        'publication_month', 'edition_information', 'publication_year', 'url',
#        'image_url', 'book_id', 'ratings_count', 'work_id', 'title',
#        'title_without_series'],
#       dtype='object')

# %%
# popular shelves - top user generated shelves for a book, defines genres 
raw_data['popular_shelves'][96]
# Out:
# [{'count': '7173', 'name': 'to-read'},
#  {'count': '235', 'name': 'vampires'},
#  {'count': '195', 'name': 'currently-reading'},
#  {'count': '194', 'name': 'young-adult'},
#  {'count': '186', 'name': 'favorites'},
#  {'count': '109', 'name': 'fantasy'},
#  {'count': '104', 'name': 'vampire'},
#  {'count': '81', 'name': 'owned'},
#  {'count': '80', 'name': 'books-i-own'},
#  {'count': '77', 'name': 'ya'},
#  {'count': '76', 'name': 'series'},
#  {'count': '73', 'name': 'paranormal'},
#  {'count': '50', 'name': 'supernatural'},
#  {'count': '42', 'name': 'heather-brewer'},
#  {'count': '41', 'name': 'fiction'},
#  {'count': '37', 'name': 'horror'},
#  {'count': '31', 'name': 'teen'},
#  {'count': '31', 'name': 'urban-fantasy'},
#  {'count': '30', 'name': 'the-chronicles-of-vladimir-tod'},
#  {'count': '30', 'name': 'vladimir-tod'},
#  {'count': '21', 'name': 'romance'},
#  {'count': '21', 'name': 'library'},
#  {'count': '18', 'name': 'owned-books'},
#  {'count': '18', 'name': 'to-buy'},
#  {'count': '16', 'name': 'high-school'},
#  {'count': '15', 'name': 'my-books'},
#  {'count': '15', 'name': 'chronicles-of-vladimir-tod'},
#  {'count': '14', 'name': 'default'},
#  {'count': '14', 'name': 'action'},
#  {'count': '13', 'name': 'vlad'},
#  {'count': '13', 'name': 'vampire-books'},
#  {'count': '12', 'name': 'ya-fiction'},
#  {'count': '11', 'name': 'i-own'},
#  {'count': '10', 'name': 'have'},
#  {'count': '10', 'name': 'my-library'},
#  {'count': '10', 'name': '7th-grade'},
#  {'count': '9', 'name': 'ya-paranormal'},
#  {'count': '9', 'name': 'completed-series'},
#  {'count': '9', 'name': 'favorite-books'},
#  {'count': '9', 'name': 'ya-fantasy'},
#  {'count': '8', 'name': 'novels'},
#  {'count': '8', 'name': 'school'},
#  {'count': '8', 'name': 'vamps'},
#  {'count': '8', 'name': 'young-adult-fiction'},
#  {'count': '8', 'name': 'read-in-2010'},
#  {'count': '8', 'name': 'books'},
#  {'count': '8', 'name': 'wish-list'},
#  {'count': '7', 'name': 'mystery'},
#  {'count': '7', 'name': 'favourites'},
#  {'count': '7', 'name': 'favorite-series'},
#  {'count': '7', 'name': 'need-to-buy'},
#  {'count': '7', 'name': 'ya-lit'},
#  {'count': '7', 'name': 'vladimir-todd'},
#  {'count': '6', 'name': 'finished'},
#  {'count': '6', 'name': 'paranormal-romance'},
#  {'count': '6', 'name': 'finished-series'},
#  {'count': '6', 'name': 'books-i-have'},
#  {'count': '6', 'name': 'favorite'},
#  {'count': '6', 'name': 'want-to-read'},
#  {'count': '6', 'name': 'death'},
#  {'count': '6', 'name': 'ya-books'},
#  {'count': '6', 'name': 'part-of-a-series'},
#  {'count': '6', 'name': 'best-books-ever'},
#  {'count': '5', 'name': 'shelfari-favorites'},
#  {'count': '5', 'name': 'paranormal-fantasy'},
#  {'count': '5', 'name': 'audiobook'},
#  {'count': '5', 'name': 'audiobooks'},
#  {'count': '5', 'name': 'own-it'},
#  {'count': '5', 'name': '5-stars'},
#  {'count': '5', 'name': '8th-grade'},
#  {'count': '5', 'name': 'my-favorites'},
#  {'count': '5', 'name': 'ebook'},
#  {'count': '4', 'name': 'read-again'},
#  {'count': '4', 'name': 'on-my-shelf'},
#  {'count': '4', 'name': 'young-adult-fantasy'},
#  {'count': '4', 'name': 'ya-read'},
#  {'count': '4', 'name': '4-stars'},
#  {'count': '4', 'name': 'drama'},
#  {'count': '4', 'name': 'love'},
#  {'count': '4', 'name': 'coming-of-age'},
#  {'count': '4', 'name': 'middle-school'},
#  {'count': '4', 'name': 're-read'},
#  {'count': '4', 'name': 'kindle'},
#  {'count': '4', 'name': 'magic'},
#  {'count': '4', 'name': 'urban'},
#  {'count': '4', 'name': 'want-to-own'},
#  {'count': '4', 'name': 'reviewed'},
#  {'count': '4', 'name': 'family'},
#  {'count': '4', 'name': 'teen-books'},
#  {'count': '4', 'name': 'mythical-creatures'},
#  {'count': '4', 'name': 'vlad-tod'},
#  {'count': '4', 'name': 'ebooks'},
#  {'count': '4', 'name': 'library-books'},
#  {'count': '4', 'name': 'audio'},
#  {'count': '4', 'name': '2011-books'},
#  {'count': '4', 'name': 'teens'},
#  {'count': '3', 'name': 'series-book-5'},
#  {'count': '3', 'name': 'auth-heather-brewer'},
#  {'count': '3', 'name': 'series-chronicles-of-vladimir-tod'},
#  {'count': '3', 'name': 'high-school-life'}]

# %%
display(raw_data['similar_books'][96]) # list of books that users who like the current book also like

display(raw_data.iloc[96,:])
# Out:
# ['25861113',
#  '7430195',
#  '18765937',
#  '6120544',
#  '3247550',
#  '9266753',
#  '6976966',
#  '25764778',
#  '17696585',
#  '23256849',
#  '642463',
#  '2842796',
#  '263172',
#  '10874337']
# isbn
# text_reviews_count                                                      9
# series                                                           [176160]
# country_code                                                           US
# language_code                                                         eng
# popular_shelves         [{'count': '7173', 'name': 'to-read'}, {'count...
# asin                                                           B0042JSOQC
# is_ebook                                                             true
# average_rating                                                       4.35
# kindle_asin                                                    B004IYJDXY
# similar_books           [25861113, 7430195, 18765937, 6120544, 3247550...
# description             It all comes down to this.\nVlad's running out...
# format
# link                    https://www.goodreads.com/book/show/10099492-t...
# authors                             [{'author_id': '293603', 'role': ''}]
# publisher
# num_pages
# publication_day
# isbn13
# publication_month
# edition_information
# publication_year
# url                     https://www.goodreads.com/book/show/10099492-t...
# image_url               https://s.gr-assets.com/assets/nophoto/book/11...
# book_id                                                          10099492
# ratings_count                                                         152
# work_id                                                          10800440
# title                   Twelfth Grade Kills (The Chronicles of Vladimi...
# title_without_series    Twelfth Grade Kills (The Chronicles of Vladimi...
# Name: 96, dtype: object

# %% [markdown]
# ### Checks for 'similar_books'
#
# Are they book ids? or ISBNs?

# %%
raw_data[raw_data['book_id'] == 7430195]
# Out:
# Empty DataFrame
# Columns: [isbn, text_reviews_count, series, country_code, language_code, popular_shelves, asin, is_ebook, average_rating, kindle_asin, similar_books, description, format, link, authors, publisher, num_pages, publication_day, isbn13, publication_month, edition_information, publication_year, url, image_url, book_id, ratings_count, work_id, title, title_without_series]
# Index: []
#
# [0 rows x 29 columns]

# %%
mask = raw_data.isbn.apply(lambda x: '25861113' == x) # 
raw_data[mask]
# Out:
# Empty DataFrame
# Columns: [isbn, text_reviews_count, series, country_code, language_code, popular_shelves, asin, is_ebook, average_rating, kindle_asin, similar_books, description, format, link, authors, publisher, num_pages, publication_day, isbn13, publication_month, edition_information, publication_year, url, image_url, book_id, ratings_count, work_id, title, title_without_series]
# Index: []
#
# [0 rows x 29 columns]

# %%
# check entire dataset for similar books
